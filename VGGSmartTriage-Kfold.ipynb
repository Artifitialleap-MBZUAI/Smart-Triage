# %%
import os
import tensorflow as tf
import numpy as np #adds support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import pandas as pd #data structures and operations for manipulating numerical tables and time series
import sys # system path io
import glob #glob module is used to retrieve files/pathnames matching a specified pattern
from tqdm import tqdm # show progress bar when a loop is running
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
from plotly import tools
from plotly.graph_objs import *
from plotly.graph_objs.layout import Margin, YAxis, XAxis
init_notebook_mode()
import matplotlib.pyplot as plt
from matplotlib import patches as patches
from pathlib import Path
import xml.etree.ElementTree as ET
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix
from keras.applications.densenet import DenseNet121, preprocess_input
from sklearn.model_selection import KFold, StratifiedKFold
from keras.applications.mobilenet_v2 import MobileNetV2,preprocess_input
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications.mobilenet import MobileNet,preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras import backend as K
import io
from google.colab import drive
from sklearn.model_selection import KFold, StratifiedKFold,LeaveOneOut
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras import backend as K
from keras.callbacks import EarlyStopping
import shutil
import statistics
from keras.models import Model
from tensorflow.keras import layers
drive.mount('/content/gdrive')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Structure: Diagnosis, Triage_Level
#NEED TO CODE FOR THE ZERO TRIAGE SCORE!
#Not real scores!
LookUp_Dictionary  = {
  'burns1':1,
  'burns2': 2,
  'burns3':10 ,
  'BacterialInfections': 5, 
  'NailDiseases':2 ,
  'ContactDermatitis':6,
  'UrticariaHives':3,
  'Others':0,
  'wounds': 7,
  'ViralInfections':5
}
print(LookUp_Dictionary)
# Out:
# {'burns1': 1, 'burns2': 2, 'burns3': 10, 'BacterialInfections': 5, 'NailDiseases': 2, 'ContactDermatitis': 6, 'UrticariaHives': 3, 'Others': 0, 'wounds': 7, 'ViralInfections': 5}

# %%
IMAGE_SIZE=[250,250]
batch_size=32
NN  = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)  
#MobileNet(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)   
for layer in NN.layers:
    layer.trainable = False
# layers creation - Here more can be added
x = layers.Flatten()(NN.output)
x = layers.Dense(1000, activation='relu')(x)
prediction = layers.Dense(10, activation='softmax')(x)
# creating a model object
model = Model(inputs=NN.input, outputs=prediction)
sgd = tf.keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(
  loss='categorical_crossentropy',

  optimizer='sgd',

  metrics=['accuracy'] 

)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
import PIL
X=[]
Y=[]
base_dir="/content/gdrive/MyDrive/MBZUAI/Smart Triage/Potential Datasets/SkinBurns"
labels_list=['burns2','burns1','burns3','BacterialInfections', 'NailDiseases','ContactDermatitis','UrticariaHives','Others','wounds','ViralInfections']
dir=os.getcwd()
for directory in labels_list:
    print(directory)
    #print(len(os.listdir(base_dir+'/'+directory)))
    for files in os.listdir(base_dir+'/'+directory):
        #img = Image.open(directory+'/'+files)
        #img = img.convert('L')
        #img = img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
        X.append(directory+'/'+files)
        #X.append([np.array(img)])
        current_index=labels_list.index(directory)
        Y.append(current_index)
X=np.asarray(X)
Y=np.asarray(Y)
# Out:
# burns2
# burns1
# burns3
# BacterialInfections
# NailDiseases
# ContactDermatitis
# UrticariaHives
# Others
# wounds
# ViralInfections

# %%
# !mkdir  validation
# !mkdir  validation/burns2
# !mkdir  validation/burns1
# !mkdir  validation/burns3
# !mkdir  validation/BacterialInfections
# !mkdir  validation/NailDiseases
# !mkdir  validation/ContactDermatitis
# !mkdir  validation/UrticariaHives
# !mkdir  validation/Others
# !mkdir  validation/wounds
# !mkdir  validation/ViralInfections

# %%
#kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
cvscores = []

validation_path="validation"
train_path= '/content/gdrive/MyDrive/MBZUAI/Smart Triage/Potential Datasets/SkinBurns/'
#skf = StratifiedKFold(n_splits=2, shuffle=True)
#skf.get_n_splits(X, Y)
accuracy_list= list()
precision_list=list()
f1_list=list()
microprecision_list=list()
microf1_list=list()
means, mins, maxs = list(),list(),list()
f1means, f1mins, f1maxs = list(),list(),list()
microf1means, microf1mins, microf1maxs = list(),list(),list()
precmeans, precmins, precmaxs = list(),list(),list()
microprecmeans, microprecmins, microprecmaxs = list(),list(),list()

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7,min_delta=.001,mode='auto')
foldNum=0
k=5
skf = StratifiedKFold(n_splits=k, shuffle=True)

for train_index, val_index in skf.split(X, Y):
             
       foldNum+=1
       model.compile(loss='categorical_crossentropy', optimizer='sgd',  metrics=['accuracy'] )
       print("Results for fold",foldNum)
       X_train, X_val = X[train_index], X[val_index]
       Y_train, Y_val = Y[train_index], Y[val_index]
       for eachindex in range(len(X_val)):
           shutil.move('/content/gdrive/MyDrive/MBZUAI/Smart Triage/Potential Datasets/SkinBurns/'+X_val[eachindex], 
                    'validation/'+X_val[eachindex])
       
       #Start ImageClassification Model
       train_datagen = ImageDataGenerator(rotation_range=20, horizontal_flip=True,  vertical_flip=True, brightness_range=[0.7,1.2], preprocessing_function=preprocess_input)

       validation_datagen = ImageDataGenerator( preprocessing_function=preprocess_input)
       train_generator = train_datagen.flow_from_directory(
            train_path,
            shuffle= True,
            target_size=IMAGE_SIZE,
            batch_size=32,
            subset='training')
       validation_generator = validation_datagen.flow_from_directory(
            validation_path,
            target_size=IMAGE_SIZE,
            batch_size=32,
            shuffle=False)  
       
       #history=
       model.fit(train_generator, 
                        epochs=40,
                        validation_data = validation_generator,
                        steps_per_epoch=int(len(X_train) // batch_size),
                        validation_steps=int(len(X_val) // batch_size),
                        callbacks=[callback])
       predictions = model.predict(validation_generator, verbose=1)
       #score = model.evaluate(validation_generator,batch_size =32)
       #print('eval', score)
       yPredictions = np.argmax(predictions, axis=1)
       true_classes = validation_generator.classes
       # evaluate validation performance
       #print("***Performance on Validation data***")
       accuracy=accuracy_score(true_classes, yPredictions)
       f1=f1_score(true_classes, yPredictions,average='macro')
       microf1= f1_score(true_classes, yPredictions,average='micro')
       precision= precision_score(true_classes, yPredictions,average='macro')
       microprecision= precision_score(true_classes, yPredictions,average='micro')
       #precision=precision_score(true_classes, yPredictions,average='weighted')
       #f1Score=f1_score(true_classes, yPredictions, average='weighted') 
       #print("Accuracy  : {}".format(accuracy))
       #print("Precision : {}".format(precision))
       #print("f1Score : {}".format(f1Score))
       #cm=confusion_matrix(true_classes, yPredictions)
       accuracy_list.append(accuracy)
       f1_list.append(f1)
       precision_list.append(precision)
       microf1_list.append(microf1)
       microprecision_list.append(microprecision)
       #print(cm)
       #valAcc, valPrec, valFScore = my_metrics(true_classes, yPredictions)
       for returnindex in range(len(X_val)):
            shutil.move('validation/'+X_val[returnindex],'/content/gdrive/MyDrive/MBZUAI/Smart Triage/Potential Datasets/SkinBurns/'+X_val[returnindex])
#gotta change this to F1
k_mean=statistics.mean(accuracy_list)
k_max=max(accuracy_list)
k_min=min(accuracy_list)
means.append(k_mean)
mins.append(k_mean - k_min)
maxs.append(k_max - k_mean)
#==================
f1_mean=statistics.mean(f1_list)
f1_max=max(f1_list)
f1_min=min(f1_list)
f1means.append(f1_mean)
f1mins.append(f1_mean - f1_min)
f1maxs.append(f1_max - f1_mean)
#========================
prec_mean=statistics.mean(precision_list)
prec_max=max(precision_list)
prec_min=min(precision_list)
precmeans.append(prec_mean)
precmins.append(prec_mean - prec_min)
precmaxs.append(prec_max - prec_mean)
#==========================
microprec_mean=statistics.mean(microprecision_list)
microprec_max=max(microprecision_list)
microprec_min=min(microprecision_list)
microprecmeans.append(microprec_mean)
microprecmins.append(microprec_mean - microprec_min)
microprecmaxs.append(microprec_max - microprec_mean)
#===========================
microf1_mean=statistics.mean(microf1_list)
microf1_max=max(microf1_list)
microf1_min=min(microf1_list)
microf1means.append(microf1_mean)
microf1mins.append(microf1_mean - microf1_min)
microf1maxs.append(microf1_max - microf1_mean)

print('Image_size and batch_size')
print(IMAGE_SIZE,batch_size)
print('Minimum Accuracy')
print(mins)
print('Maximum Accuracy')
print(maxs)
print('Average Accuracy')
print(means)
#=============
print('Minimum macro precision')
print(precmins)
print('Maximum macro precision')
print(precmaxs)
print('Average macro precision')
print(precmeans)
#===============
print('Minimum macro F1')
print(f1mins)
print('Maximum macro F1')
print(f1maxs)
print('Average macro F1')
print(f1means)
#===============
print('Minimum micro precision')
print(microprecmins)
print('Maximum micro precision')
print(microprecmaxs)
print('Average micro precision')
print(microprecmeans)
#===============
print('Minimum micro F1')
print(microf1mins)
print('Maximum micro F1')
print(microf1maxs)
print('Average micro F1')
print(microf1means)
#plt.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
# plot the ideal case in a separate color
#plt.plot(folds, [ideal for _ in range(len(folds))], color='r')
# show the plot
#plt.show()
   #model.fit_generator(train_generator, epochs=50,  verbose = 0, validation_data=test_generator)

   #scores = model.evaluate(X[test], Y[test], verbose=0)
   #print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Results for fold 1
# Found 3084 images belonging to 10 classes.
# Found 769 images belonging to 10 classes.
# Epoch 1/40
# 96/96 [==============================] - 1690s 17s/step - loss: 1.9433 - accuracy: 0.4538 - val_loss: 1.3854 - val_accuracy: 0.5638
# Epoch 2/40
# 96/96 [==============================] - 68s 712ms/step - loss: 1.3717 - accuracy: 0.5360 - val_loss: 1.2208 - val_accuracy: 0.5664
# Epoch 3/40
# 96/96 [==============================] - 69s 716ms/step - loss: 1.2671 - accuracy: 0.5416 - val_loss: 1.1662 - val_accuracy: 0.5625
# Epoch 4/40
# 96/96 [==============================] - 69s 715ms/step - loss: 1.1910 - accuracy: 0.5662 - val_loss: 1.1500 - val_accuracy: 0.5612
# Epoch 5/40
# 96/96 [==============================] - 68s 712ms/step - loss: 1.1355 - accuracy: 0.5724 - val_loss: 1.1279 - val_accuracy: 0.5729
# Epoch 6/40
# 96/96 [==============================] - 69s 713ms/step - loss: 1.1160 - accuracy: 0.5763 - val_loss: 1.1530 - val_accuracy: 0.5547
# Epoch 7/40
# 96/96 [==============================] - 68s 712ms/step - loss: 1.0732 - accuracy: 0.5934 - val_loss: 1.0342 - val_accuracy: 0.5859
# Epoch 8/40
# 96/96 [==============================] - 69s 715ms/step - loss: 1.0398 - accuracy: 0.5953 - val_loss: 0.9674 - val_accuracy: 0.6107
# Epoch 9/40
# 96/96 [==============================] - 69s 719ms/step - loss: 1.0046 - accuracy: 0.6124 - val_loss: 0.9307 - val_accuracy: 0.6289
# Epoch 10/40
# 96/96 [==============================] - 69s 718ms/step - loss: 0.9953 - accuracy: 0.6225 - val_loss: 0.9549 - val_accuracy: 0.6224
# Epoch 11/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.9793 - accuracy: 0.6237 - val_loss: 0.9425 - val_accuracy: 0.6211
# Epoch 12/40
# 96/96 [==============================] - 69s 716ms/step - loss: 0.9610 - accuracy: 0.6324 - val_loss: 1.0250 - val_accuracy: 0.6081
# Epoch 13/40
# 96/96 [==============================] - 69s 713ms/step - loss: 0.9474 - accuracy: 0.6389 - val_loss: 0.8801 - val_accuracy: 0.6523
# Epoch 14/40
# 96/96 [==============================] - 69s 714ms/step - loss: 0.9510 - accuracy: 0.6343 - val_loss: 0.9435 - val_accuracy: 0.6250
# Epoch 15/40
# 96/96 [==============================] - 70s 729ms/step - loss: 0.9213 - accuracy: 0.6455 - val_loss: 1.0463 - val_accuracy: 0.5911
# Epoch 16/40
# 96/96 [==============================] - 68s 712ms/step - loss: 0.9027 - accuracy: 0.6412 - val_loss: 0.8684 - val_accuracy: 0.6549
# Epoch 17/40
# 96/96 [==============================] - 69s 717ms/step - loss: 0.8868 - accuracy: 0.6566 - val_loss: 0.8469 - val_accuracy: 0.6719
# Epoch 18/40
# 96/96 [==============================] - 69s 714ms/step - loss: 0.8862 - accuracy: 0.6468 - val_loss: 0.9113 - val_accuracy: 0.6380
# Epoch 19/40
# 96/96 [==============================] - 69s 715ms/step - loss: 0.8800 - accuracy: 0.6550 - val_loss: 1.0297 - val_accuracy: 0.5885
# Epoch 20/40
# 96/96 [==============================] - 69s 714ms/step - loss: 0.8607 - accuracy: 0.6743 - val_loss: 0.8803 - val_accuracy: 0.6589
# Epoch 21/40
# 96/96 [==============================] - 69s 715ms/step - loss: 0.8559 - accuracy: 0.6619 - val_loss: 0.9001 - val_accuracy: 0.6628
# Epoch 22/40
# 96/96 [==============================] - 68s 713ms/step - loss: 0.8457 - accuracy: 0.6792 - val_loss: 0.8698 - val_accuracy: 0.6549
# Epoch 23/40
# 96/96 [==============================] - 69s 716ms/step - loss: 0.8616 - accuracy: 0.6658 - val_loss: 0.9148 - val_accuracy: 0.6536
# Epoch 24/40
# 96/96 [==============================] - 68s 712ms/step - loss: 0.8271 - accuracy: 0.6760 - val_loss: 0.8411 - val_accuracy: 0.6758
# Epoch 25/40
# 96/96 [==============================] - 69s 715ms/step - loss: 0.8297 - accuracy: 0.6789 - val_loss: 0.9560 - val_accuracy: 0.6094
# Epoch 26/40
# 96/96 [==============================] - 69s 714ms/step - loss: 0.8200 - accuracy: 0.6799 - val_loss: 0.8702 - val_accuracy: 0.6536
# Epoch 27/40
# 96/96 [==============================] - 69s 715ms/step - loss: 0.8014 - accuracy: 0.6871 - val_loss: 0.8702 - val_accuracy: 0.6510
# Epoch 28/40
# 96/96 [==============================] - 69s 716ms/step - loss: 0.7915 - accuracy: 0.6933 - val_loss: 0.8009 - val_accuracy: 0.6875
# Epoch 29/40
# 96/96 [==============================] - 69s 714ms/step - loss: 0.8016 - accuracy: 0.6884 - val_loss: 0.8443 - val_accuracy: 0.6771
# Epoch 30/40
# 96/96 [==============================] - 68s 712ms/step - loss: 0.7864 - accuracy: 0.6874 - val_loss: 0.8157 - val_accuracy: 0.6680
# Epoch 31/40
# 96/96 [==============================] - 68s 711ms/step - loss: 0.7777 - accuracy: 0.6917 - val_loss: 0.8880 - val_accuracy: 0.6628
# Epoch 32/40
# 96/96 [==============================] - 69s 718ms/step - loss: 0.7657 - accuracy: 0.7041 - val_loss: 0.9329 - val_accuracy: 0.6276
# Epoch 33/40
# 96/96 [==============================] - 68s 712ms/step - loss: 0.7396 - accuracy: 0.7130 - val_loss: 0.8023 - val_accuracy: 0.6823
# Epoch 34/40
# 96/96 [==============================] - 69s 715ms/step - loss: 0.7642 - accuracy: 0.7005 - val_loss: 0.8611 - val_accuracy: 0.6458
# Epoch 35/40
# 96/96 [==============================] - 69s 716ms/step - loss: 0.7523 - accuracy: 0.7041 - val_loss: 0.9026 - val_accuracy: 0.6328
# 25/25 [==============================] - 6s 233ms/step
# Results for fold 2
# Found 3082 images belonging to 10 classes.
# Found 771 images belonging to 10 classes.
# Epoch 1/40
# 96/96 [==============================] - 70s 728ms/step - loss: 0.8012 - accuracy: 0.6997 - val_loss: 0.6558 - val_accuracy: 0.7240
# Epoch 2/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.7719 - accuracy: 0.7036 - val_loss: 0.7448 - val_accuracy: 0.6875
# Epoch 3/40
# 96/96 [==============================] - 69s 716ms/step - loss: 0.7594 - accuracy: 0.7023 - val_loss: 0.6577 - val_accuracy: 0.7344
# Epoch 4/40
# 96/96 [==============================] - 69s 716ms/step - loss: 0.7602 - accuracy: 0.7026 - val_loss: 0.7695 - val_accuracy: 0.6953
# Epoch 5/40
# 96/96 [==============================] - 69s 720ms/step - loss: 0.7524 - accuracy: 0.7089 - val_loss: 0.7425 - val_accuracy: 0.7109
# Epoch 6/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.7540 - accuracy: 0.7138 - val_loss: 0.6612 - val_accuracy: 0.7396
# Epoch 7/40
# 96/96 [==============================] - 69s 721ms/step - loss: 0.7567 - accuracy: 0.7085 - val_loss: 0.6106 - val_accuracy: 0.7552
# Epoch 8/40
# 96/96 [==============================] - 69s 721ms/step - loss: 0.7556 - accuracy: 0.7059 - val_loss: 0.6311 - val_accuracy: 0.7435
# Epoch 9/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.7256 - accuracy: 0.7157 - val_loss: 0.6564 - val_accuracy: 0.7305
# Epoch 10/40
# 96/96 [==============================] - 69s 721ms/step - loss: 0.7172 - accuracy: 0.7282 - val_loss: 0.7503 - val_accuracy: 0.6979
# Epoch 11/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.7152 - accuracy: 0.7243 - val_loss: 0.6462 - val_accuracy: 0.7370
# Epoch 12/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.7168 - accuracy: 0.7249 - val_loss: 0.6867 - val_accuracy: 0.7383
# Epoch 13/40
# 96/96 [==============================] - 69s 724ms/step - loss: 0.7207 - accuracy: 0.7226 - val_loss: 0.5983 - val_accuracy: 0.7695
# Epoch 14/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.6983 - accuracy: 0.7370 - val_loss: 0.6265 - val_accuracy: 0.7578
# Epoch 15/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.6906 - accuracy: 0.7233 - val_loss: 0.6379 - val_accuracy: 0.7409
# Epoch 16/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.6983 - accuracy: 0.7289 - val_loss: 0.8114 - val_accuracy: 0.6745
# Epoch 17/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.6644 - accuracy: 0.7380 - val_loss: 0.7417 - val_accuracy: 0.7135
# Epoch 18/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.6876 - accuracy: 0.7305 - val_loss: 0.6689 - val_accuracy: 0.7331
# Epoch 19/40
# 96/96 [==============================] - 69s 718ms/step - loss: 0.6709 - accuracy: 0.7384 - val_loss: 0.5965 - val_accuracy: 0.7578
# Epoch 20/40
# 96/96 [==============================] - 69s 721ms/step - loss: 0.6592 - accuracy: 0.7452 - val_loss: 0.6503 - val_accuracy: 0.7344
# Epoch 21/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.6593 - accuracy: 0.7498 - val_loss: 0.6467 - val_accuracy: 0.7344
# Epoch 22/40
# 96/96 [==============================] - 69s 724ms/step - loss: 0.6672 - accuracy: 0.7479 - val_loss: 0.7062 - val_accuracy: 0.7188
# Epoch 23/40
# 96/96 [==============================] - 69s 718ms/step - loss: 0.6487 - accuracy: 0.7426 - val_loss: 0.6787 - val_accuracy: 0.7292
# Epoch 24/40
# 96/96 [==============================] - 69s 721ms/step - loss: 0.6457 - accuracy: 0.7580 - val_loss: 0.6197 - val_accuracy: 0.7383
# Epoch 25/40
# 96/96 [==============================] - 69s 723ms/step - loss: 0.6474 - accuracy: 0.7508 - val_loss: 0.6997 - val_accuracy: 0.7305
# Epoch 26/40
# 96/96 [==============================] - 69s 718ms/step - loss: 0.6314 - accuracy: 0.7551 - val_loss: 0.6696 - val_accuracy: 0.7240
# 25/25 [==============================] - 6s 234ms/step
# Results for fold 3
# Found 3082 images belonging to 10 classes.
# Found 771 images belonging to 10 classes.
# Epoch 1/40
# 96/96 [==============================] - 70s 726ms/step - loss: 0.6347 - accuracy: 0.7508 - val_loss: 0.5292 - val_accuracy: 0.8047
# Epoch 2/40
# 96/96 [==============================] - 70s 725ms/step - loss: 0.6290 - accuracy: 0.7557 - val_loss: 0.6337 - val_accuracy: 0.7292
# Epoch 3/40
# 96/96 [==============================] - 69s 718ms/step - loss: 0.6354 - accuracy: 0.7466 - val_loss: 0.5732 - val_accuracy: 0.7852
# Epoch 4/40
# 96/96 [==============================] - 69s 723ms/step - loss: 0.6245 - accuracy: 0.7630 - val_loss: 0.7032 - val_accuracy: 0.7083
# Epoch 5/40
# 96/96 [==============================] - 69s 718ms/step - loss: 0.6335 - accuracy: 0.7607 - val_loss: 0.6285 - val_accuracy: 0.7552
# Epoch 6/40
# 96/96 [==============================] - 69s 717ms/step - loss: 0.6328 - accuracy: 0.7511 - val_loss: 0.5295 - val_accuracy: 0.8021
# Epoch 7/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.6172 - accuracy: 0.7728 - val_loss: 0.6802 - val_accuracy: 0.7305
# Epoch 8/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.6446 - accuracy: 0.7518 - val_loss: 0.5852 - val_accuracy: 0.7760
# 25/25 [==============================] - 5s 215ms/step
# Results for fold 4
# Found 3082 images belonging to 10 classes.
# Found 771 images belonging to 10 classes.
# Epoch 1/40
# 96/96 [==============================] - 70s 725ms/step - loss: 0.6491 - accuracy: 0.7492 - val_loss: 0.6113 - val_accuracy: 0.7943
# Epoch 2/40
# 96/96 [==============================] - 70s 725ms/step - loss: 0.6239 - accuracy: 0.7643 - val_loss: 0.4887 - val_accuracy: 0.8151
# Epoch 3/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.6246 - accuracy: 0.7580 - val_loss: 0.7371 - val_accuracy: 0.7057
# Epoch 4/40
# 96/96 [==============================] - 69s 724ms/step - loss: 0.6074 - accuracy: 0.7705 - val_loss: 0.4699 - val_accuracy: 0.8294
# Epoch 5/40
# 96/96 [==============================] - 69s 722ms/step - loss: 0.6116 - accuracy: 0.7597 - val_loss: 0.5113 - val_accuracy: 0.8060
# Epoch 6/40
# 96/96 [==============================] - 70s 726ms/step - loss: 0.6197 - accuracy: 0.7636 - val_loss: 0.5227 - val_accuracy: 0.8164
# Epoch 7/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.5880 - accuracy: 0.7774 - val_loss: 0.4769 - val_accuracy: 0.8190
# Epoch 8/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.5766 - accuracy: 0.7702 - val_loss: 0.4890 - val_accuracy: 0.8268
# Epoch 9/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.6023 - accuracy: 0.7728 - val_loss: 0.5196 - val_accuracy: 0.7995
# Epoch 10/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.5695 - accuracy: 0.7780 - val_loss: 0.5671 - val_accuracy: 0.7917
# Epoch 11/40
# 96/96 [==============================] - 70s 723ms/step - loss: 0.5717 - accuracy: 0.7858 - val_loss: 0.4780 - val_accuracy: 0.8216
# 25/25 [==============================] - 6s 230ms/step
# Results for fold 5
# Found 3082 images belonging to 10 classes.
# Found 771 images belonging to 10 classes.
# Epoch 1/40
# 96/96 [==============================] - 70s 724ms/step - loss: 0.5781 - accuracy: 0.7708 - val_loss: 0.5354 - val_accuracy: 0.7956
# Epoch 2/40
# 96/96 [==============================] - 70s 725ms/step - loss: 0.5728 - accuracy: 0.7738 - val_loss: 0.5220 - val_accuracy: 0.7969
# Epoch 3/40
# 96/96 [==============================] - 70s 725ms/step - loss: 0.5861 - accuracy: 0.7777 - val_loss: 0.5165 - val_accuracy: 0.7891
# Epoch 4/40
# 96/96 [==============================] - 70s 731ms/step - loss: 0.5786 - accuracy: 0.7741 - val_loss: 0.4708 - val_accuracy: 0.8385
# Epoch 5/40
# 96/96 [==============================] - 69s 723ms/step - loss: 0.5552 - accuracy: 0.7895 - val_loss: 0.5146 - val_accuracy: 0.7904
# Epoch 6/40
# 96/96 [==============================] - 70s 727ms/step - loss: 0.5578 - accuracy: 0.7787 - val_loss: 0.4802 - val_accuracy: 0.8112
# Epoch 7/40
# 96/96 [==============================] - 69s 723ms/step - loss: 0.5511 - accuracy: 0.7911 - val_loss: 0.5752 - val_accuracy: 0.7539
# Epoch 8/40
# 96/96 [==============================] - 69s 723ms/step - loss: 0.5589 - accuracy: 0.7800 - val_loss: 0.4691 - val_accuracy: 0.8268
# Epoch 9/40
# 96/96 [==============================] - 69s 719ms/step - loss: 0.5488 - accuracy: 0.7898 - val_loss: 0.5575 - val_accuracy: 0.7930
# Epoch 10/40
# 96/96 [==============================] - 70s 724ms/step - loss: 0.5437 - accuracy: 0.7921 - val_loss: 0.4857 - val_accuracy: 0.8151
# Epoch 11/40
# 96/96 [==============================] - 69s 720ms/step - loss: 0.5348 - accuracy: 0.7951 - val_loss: 0.5641 - val_accuracy: 0.7604
# Epoch 12/40
# 96/96 [==============================] - 69s 723ms/step - loss: 0.5486 - accuracy: 0.7918 - val_loss: 0.4889 - val_accuracy: 0.8138
# Epoch 13/40
# 96/96 [==============================] - 69s 721ms/step - loss: 0.5319 - accuracy: 0.7997 - val_loss: 0.5578 - val_accuracy: 0.7773
# Epoch 14/40
# 96/96 [==============================] - 70s 728ms/step - loss: 0.5247 - accuracy: 0.7931 - val_loss: 0.5238 - val_accuracy: 0.7995
# Epoch 15/40
# 96/96 [==============================] - 70s 727ms/step - loss: 0.5345 - accuracy: 0.7911 - val_loss: 0.5625 - val_accuracy: 0.7826
# 25/25 [==============================] - 5s 218ms/step
# Image_size and batch_size
# [250, 250] 32
# Minimum Accuracy
# [0.11516059227625608]
# Maximum Accuracy
# [0.07386148399643111]
# Average Accuracy
# [0.7471501891553198]
# Minimum macro precision
# [0.15117172435875748]
# Maximum macro precision
# [0.07815172628503964]
# Average macro precision
# [0.7788924897649716]
# Minimum macro F1
# [0.11020661423906863]
# Maximum macro F1
# [0.07798509304791101]
# Average macro F1
# [0.7286570280947059]
# Minimum micro precision
# [0.11516059227625608]
# Maximum micro precision
# [0.07386148399643111]
# Average micro precision
# [0.7471501891553198]
# Minimum micro F1
# [0.11516059227625608]
# Maximum micro F1
# [0.07386148399643111]
# Average micro F1
# [0.7471501891553198]

# %% [markdown]
# Image_size and batch_size
# [250, 250] 32
# Minimum Accuracy
# [0.11516059227625608]
# Maximum Accuracy
# [0.07386148399643111]
# Average Accuracy
# [0.7471501891553198]
# Minimum macro precision
# [0.15117172435875748]
# Maximum macro precision
# [0.07815172628503964]
# Average macro precision
# [0.7788924897649716]
# Minimum macro F1
# [0.11020661423906863]
# Maximum macro F1
# [0.07798509304791101]
# Average macro F1
# [0.7286570280947059]
# Minimum micro precision
# [0.11516059227625608]
# Maximum micro precision
# [0.07386148399643111]
# Average micro precision
# [0.7471501891553198]
# Minimum micro F1
# [0.11516059227625608]
# Maximum micro F1
# [0.07386148399643111]
# Average micro F1
# [0.7471501891553198]
